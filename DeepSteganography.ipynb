# %%
# Imports necessary libraries and modules
from itertools import islice
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import torch
from torch.autograd import Variable
from torch import utils
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import os
import pickle
from torchvision import datasets, utils
import torchvision.transforms as transforms
from torchvision.transforms import ToPILImage
from random import shuffle
from IPython.display import Image

# %%
# Directory path
os.chdir("..")
cwd = '/content/new_data'

# Hyper Parameters
num_epochs = 3
batch_size = 2
learning_rate = 0.0001
beta = 1


MODELS_PATH = '/output/'
VALID_PATH = cwd+'/val/'
TRAIN_PATH = cwd+'/train/'
TEST_PATH = cwd+'/test/'

if not os.path.exists(MODELS_PATH): os.mkdir(MODELS_PATH)

# %%
def customized_loss(S_prime, C_prime, S, C, B):

    loss_cover = torch.nn.functional.mse_loss(C_prime, C)
    loss_secret = torch.nn.functional.mse_loss(S_prime, S)
    loss_all = loss_cover + B * loss_secret
    return loss_all, loss_cover, loss_secret

def denormalize(image, std, mean):

    for t in range(3):
        image[t, :, :] = (image[t, :, :] * std[t]) + mean[t]
    return image

def imshow(img, idx, learning_rate, beta):

    img = denormalize(img, std, mean)
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.title('Example '+str(idx)+', lr='+str(learning_rate)+', B='+str(beta))
    plt.show()
    return

def gaussian(tensor, mean=0, stddev=0.1):

    noise = torch.nn.init.normal(torch.Tensor(tensor.size()), 0, 0.1)
    return Variable(tensor + noise)

# %%
# Preparation Network (2 conv layers)
class PrepNetwork(nn.Module):
    def __init__(self):
        super(PrepNetwork, self).__init__()
        self.initialP3 = nn.Sequential(
            nn.Conv2d(3, 50, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=3, padding=1),
            nn.ReLU())
        self.initialP4 = nn.Sequential(
            nn.Conv2d(3, 50, kernel_size=4, padding=1),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=4, padding=2),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=4, padding=1),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=4, padding=2),
            nn.ReLU())
        self.initialP5 = nn.Sequential(
            nn.Conv2d(3, 50, kernel_size=5, padding=2),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=5, padding=2),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=5, padding=2),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=5, padding=2),
            nn.ReLU())
        self.finalP3 = nn.Sequential(
            nn.Conv2d(150, 50, kernel_size=3, padding=1),
            nn.ReLU())
        self.finalP4 = nn.Sequential(
            nn.Conv2d(150, 50, kernel_size=4, padding=1),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=4, padding=2),
            nn.ReLU())
        self.finalP5 = nn.Sequential(
            nn.Conv2d(150, 50, kernel_size=5, padding=2),
            nn.ReLU())

    def forward(self, p):
        p1 = self.initialP3(p)
        p2 = self.initialP4(p)
        p3 = self.initialP5(p)
        mid = torch.cat((p1, p2, p3), 1)
        p4 = self.finalP3(mid)
        p5 = self.finalP4(mid)
        p6 = self.finalP5(mid)
        out = torch.cat((p4, p5, p6), 1)
        return out

# Hiding Network (5 conv layers)
class HidingNetwork(nn.Module):
    def __init__(self):
        super(HidingNetwork, self).__init__()
        self.initialH3 = nn.Sequential(
            nn.Conv2d(153, 50, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=3, padding=1),
            nn.ReLU())
        self.initialH4 = nn.Sequential(
            nn.Conv2d(153, 50, kernel_size=4, padding=1),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=4, padding=2),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=4, padding=1),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=4, padding=2),
            nn.ReLU())
        self.initialH5 = nn.Sequential(
            nn.Conv2d(153, 50, kernel_size=5, padding=2),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=5, padding=2),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=5, padding=2),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=5, padding=2),
            nn.ReLU())
        self.finalH3 = nn.Sequential(
            nn.Conv2d(150, 50, kernel_size=3, padding=1),
            nn.ReLU())
        self.finalH4 = nn.Sequential(
            nn.Conv2d(150, 50, kernel_size=4, padding=1),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=4, padding=2),
            nn.ReLU())
        self.finalH5 = nn.Sequential(
            nn.Conv2d(150, 50, kernel_size=5, padding=2),
            nn.ReLU())
        self.finalH = nn.Sequential(
            nn.Conv2d(150, 3, kernel_size=1, padding=0))

    def forward(self, h):
        h1 = self.initialH3(h)
        h2 = self.initialH4(h)
        h3 = self.initialH5(h)
        mid = torch.cat((h1, h2, h3), 1)
        h4 = self.finalH3(mid)
        h5 = self.finalH4(mid)
        h6 = self.finalH5(mid)
        mid2 = torch.cat((h4, h5, h6), 1)
        out = self.finalH(mid2)
        out_noise = gaussian(out.data, 0, 0.1)
        return out, out_noise

# Reveal Network (2 conv layers)
class RevealNetwork(nn.Module):
    def __init__(self):
        super(RevealNetwork, self).__init__()
        self.initialR3 = nn.Sequential(
            nn.Conv2d(3, 50, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=3, padding=1),
            nn.ReLU())
        self.initialR4 = nn.Sequential(
            nn.Conv2d(3, 50, kernel_size=4, padding=1),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=4, padding=2),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=4, padding=1),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=4, padding=2),
            nn.ReLU())
        self.initialR5 = nn.Sequential(
            nn.Conv2d(3, 50, kernel_size=5, padding=2),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=5, padding=2),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=5, padding=2),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=5, padding=2),
            nn.ReLU())
        self.finalR3 = nn.Sequential(
            nn.Conv2d(150, 50, kernel_size=3, padding=1),
            nn.ReLU())
        self.finalR4 = nn.Sequential(
            nn.Conv2d(150, 50, kernel_size=4, padding=1),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=4, padding=2),
            nn.ReLU())
        self.finalR5 = nn.Sequential(
            nn.Conv2d(150, 50, kernel_size=5, padding=2),
            nn.ReLU())
        self.finalR = nn.Sequential(
            nn.Conv2d(150, 3, kernel_size=1, padding=0))

    def forward(self, r):
        r1 = self.initialR3(r)
        r2 = self.initialR4(r)
        r3 = self.initialR5(r)
        mid = torch.cat((r1, r2, r3), 1)
        r4 = self.finalR3(mid)
        r5 = self.finalR4(mid)
        r6 = self.finalR5(mid)
        mid2 = torch.cat((r4, r5, r6), 1)
        out = self.finalR(mid2)
        return out

# Join three networks in one module
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.m1 = PrepNetwork()
        self.m2 = HidingNetwork()
        self.m3 = RevealNetwork()

    def forward(self, secret, cover):
        x_1 = self.m1(secret)
        mid = torch.cat((x_1, cover), 1)
        x_2, x_2_noise = self.m2(mid)
        x_3 = self.m3(x_2_noise)
        return x_2, x_3

# %%
# Creates net object
net = Net()

# %% [markdown]
# We create loaders for normalized training, validation and test sets

# %%
# Creates training set
train_loader = torch.utils.data.DataLoader(
        datasets.ImageFolder(
        TRAIN_PATH,
        transforms.Compose([
        transforms.Scale(256),
        transforms.RandomCrop(224),
        transforms.ToTensor(),
        transforms.Normalize(mean=mean,
        std=std)
        ])), batch_size=batch_size, num_workers=1,
        pin_memory=True, shuffle=True, drop_last=True)

# Creates test set
test_loader = torch.utils.data.DataLoader(
        datasets.ImageFolder(
        TEST_PATH,
        transforms.Compose([
        transforms.Scale(256),
        transforms.RandomCrop(224),
        transforms.ToTensor(),
        transforms.Normalize(mean=mean,
        std=std)
        ])), batch_size=2, num_workers=1,
        pin_memory=True, shuffle=True, drop_last=True)
# Out:
# /usr/local/lib/python3.6/dist-packages/torchvision/transforms/transforms.py:220: UserWarning: The use of the transforms.Scale transform is deprecated, please use transforms.Resize instead.
#   "please use transforms.Resize instead.")

# %% [markdown]
# We train the model and validate it, saving the best model. We use Adam as an optimizer as the paper specifies.

# %%
def train_model(train_loader, beta, learning_rate):

    # Save optimizer
    optimizer = optim.Adam(net.parameters(), lr=learning_rate)

    loss_history = []
    # Iterate over batches performing forward and backward passes
    for epoch in range(num_epochs):

        # Train mode
        net.train()

        train_losses = []
        # Train one epoch
        for idx, train_batch in enumerate(train_loader):

            data, _  = train_batch

            # Saves secret images and secret covers
            train_covers = data[:len(data)//2]
            train_secrets = data[len(data)//2:]

            # Creates variable from secret and cover images
            train_secrets = Variable(train_secrets, requires_grad=False)
            train_covers = Variable(train_covers, requires_grad=False)

            # Forward + Backward + Optimize
            optimizer.zero_grad()
            train_hidden, train_output = net(train_secrets, train_covers)

            # Calculate loss and perform backprop
            train_loss, train_loss_cover, train_loss_secret = customized_loss(train_output, train_hidden, train_secrets, train_covers, beta)
            train_loss.backward()
            optimizer.step()

            # Saves training loss
            # train_losses.append(train_loss.data[0])
            # loss_history.append(train_loss.data[0])

            train_losses.append(train_loss.item())
            loss_history.append(train_loss.item())

            # Prints mini-batch losses
            #print('Training: Batch {0}/{1}. Loss of {2:.4f}, cover loss of {3:.4f}, secret loss of {4:.4f}'.format(idx+1, len(train_loader), train_loss.data[0], train_loss_cover.data[0], train_loss_secret.data[0]))
            print('Training: Batch {0}/{1}. Loss of {2:.4f}, cover loss of {3:.4f}, secret loss of {4:.4f}'.format(idx+1, len(train_loader), train_loss.item(), train_loss_cover.item(), train_loss_secret.item()))

        torch.save(net.state_dict(), MODELS_PATH+'Epoch N{}.pkl'.format(epoch+1))

        mean_train_loss = np.mean(train_losses)

        # Prints epoch average loss
        print ('Epoch [{0}/{1}], Average_loss: {2:.4f}'.format(
                epoch+1, num_epochs, mean_train_loss))

    return net, mean_train_loss, loss_history

# %%
#torch.save(net.state_dict(), '/content/model')
net.load_state_dict(torch.load('/content/model'))
# Out:
# <All keys matched successfully>

# %%
net, mean_train_loss, loss_history = train_model(train_loader, beta, learning_rate)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:29: UserWarning: nn.init.normal is now deprecated in favor of nn.init.normal_.
# Training: Batch 1/208. Loss of 0.6341, cover loss of 0.0022, secret loss of 0.6319
# Training: Batch 2/208. Loss of 0.5724, cover loss of 0.0668, secret loss of 0.5055
# Training: Batch 3/208. Loss of 0.7733, cover loss of 0.0077, secret loss of 0.7656
# Training: Batch 4/208. Loss of 1.3175, cover loss of 0.0397, secret loss of 1.2778
# Training: Batch 5/208. Loss of 1.7670, cover loss of 0.0316, secret loss of 1.7353
# Training: Batch 6/208. Loss of 1.1727, cover loss of 0.0176, secret loss of 1.1551
# Training: Batch 7/208. Loss of 1.0729, cover loss of 0.0265, secret loss of 1.0464
# Training: Batch 8/208. Loss of 0.4098, cover loss of 0.0095, secret loss of 0.4003
# Training: Batch 9/208. Loss of 0.8057, cover loss of 0.0053, secret loss of 0.8004
# Training: Batch 10/208. Loss of 1.0911, cover loss of 0.0126, secret loss of 1.0785
# Training: Batch 11/208. Loss of 0.8711, cover loss of 0.0140, secret loss of 0.8571
# Training: Batch 12/208. Loss of 0.9849, cover loss of 0.0037, secret loss of 0.9813
# Training: Batch 13/208. Loss of 1.3752, cover loss of 0.0102, secret loss of 1.3650
# Training: Batch 14/208. Loss of 0.8202, cover loss of 0.0132, secret loss of 0.8070
# Training: Batch 15/208. Loss of 0.7264, cover loss of 0.0115, secret loss of 0.7149
# Training: Batch 16/208. Loss of 0.7419, cover loss of 0.0111, secret loss of 0.7308
# Training: Batch 17/208. Loss of 1.2822, cover loss of 0.0110, secret loss of 1.2712
# Training: Batch 18/208. Loss of 1.2070, cover loss of 0.0101, secret loss of 1.1969
# Training: Batch 19/208. Loss of 0.8881, cover loss of 0.0069, secret loss of 0.8811
# Training: Batch 20/208. Loss of 0.5192, cover loss of 0.0097, secret loss of 0.5095
# Training: Batch 21/208. Loss of 1.5243, cover loss of 0.0075, secret loss of 1.5168
# Training: Batch 22/208. Loss of 0.6496, cover loss of 0.0058, secret loss of 0.6438
# Training: Batch 23/208. Loss of 0.7837, cover loss of 0.0074, secret loss of 0.7763
# Training: Batch 24/208. Loss of 0.6586, cover loss of 0.0055, secret loss of 0.6532
# Training: Batch 25/208. Loss of 0.7918, cover loss of 0.0077, secret loss of 0.7841
# Training: Batch 26/208. Loss of 1.6341, cover loss of 0.0078, secret loss of 1.6263
# Training: Batch 27/208. Loss of 1.1675, cover loss of 0.0099, secret loss of 1.1577
# Training: Batch 28/208. Loss of 1.6797, cover loss of 0.0092, secret loss of 1.6705
# Training: Batch 29/208. Loss of 2.2732, cover loss of 0.0034, secret loss of 2.2698
# Training: Batch 30/208. Loss of 0.6321, cover loss of 0.0041, secret loss of 0.6280
# Training: Batch 31/208. Loss of 0.7138, cover loss of 0.0053, secret loss of 0.7084
# Training: Batch 32/208. Loss of 1.3904, cover loss of 0.0083, secret loss of 1.3821
# Training: Batch 33/208. Loss of 0.9342, cover loss of 0.0055, secret loss of 0.9287
# Training: Batch 34/208. Loss of 0.7254, cover loss of 0.0082, secret loss of 0.7172
# Training: Batch 35/208. Loss of 0.9160, cover loss of 0.0027, secret loss of 0.9133
# Training: Batch 36/208. Loss of 1.1075, cover loss of 0.0023, secret loss of 1.1052
# Training: Batch 37/208. Loss of 0.7036, cover loss of 0.0035, secret loss of 0.7001
# Training: Batch 38/208. Loss of 0.8902, cover loss of 0.0035, secret loss of 0.8867
# Training: Batch 39/208. Loss of 0.8908, cover loss of 0.0041, secret loss of 0.8867
# Training: Batch 40/208. Loss of 0.9482, cover loss of 0.0038, secret loss of 0.9444
# Training: Batch 41/208. Loss of 0.3040, cover loss of 0.0066, secret loss of 0.2974
# Training: Batch 42/208. Loss of 2.8148, cover loss of 0.0035, secret loss of 2.8113
# Training: Batch 43/208. Loss of 0.7528, cover loss of 0.0040, secret loss of 0.7489
# Training: Batch 44/208. Loss of 1.5837, cover loss of 0.0081, secret loss of 1.5756
# Training: Batch 45/208. Loss of 1.2028, cover loss of 0.0020, secret loss of 1.2007
# Training: Batch 46/208. Loss of 1.3189, cover loss of 0.0020, secret loss of 1.3169
# Training: Batch 47/208. Loss of 1.3227, cover loss of 0.0039, secret loss of 1.3188
# Training: Batch 48/208. Loss of 0.5626, cover loss of 0.0022, secret loss of 0.5604
# Training: Batch 49/208. Loss of 1.0555, cover loss of 0.0041, secret loss of 1.0514
# Training: Batch 50/208. Loss of 0.3259, cover loss of 0.0034, secret loss of 0.3224
# Training: Batch 51/208. Loss of 2.0316, cover loss of 0.0022, secret loss of 2.0294
# Training: Batch 52/208. Loss of 0.6955, cover loss of 0.0010, secret loss of 0.6945
# Training: Batch 53/208. Loss of 0.3348, cover loss of 0.0049, secret loss of 0.3298
# Training: Batch 54/208. Loss of 1.6681, cover loss of 0.0055, secret loss of 1.6625
# Training: Batch 55/208. Loss of 0.8262, cover loss of 0.0060, secret loss of 0.8202
# Training: Batch 56/208. Loss of 0.9564, cover loss of 0.0041, secret loss of 0.9522
# Training: Batch 57/208. Loss of 1.7508, cover loss of 0.0008, secret loss of 1.7501
# Training: Batch 58/208. Loss of 0.9745, cover loss of 0.0016, secret loss of 0.9728
# Training: Batch 59/208. Loss of 0.9894, cover loss of 0.0043, secret loss of 0.9851
# Training: Batch 60/208. Loss of 0.6614, cover loss of 0.0025, secret loss of 0.6589
# Training: Batch 61/208. Loss of 2.6833, cover loss of 0.0032, secret loss of 2.6802
# Training: Batch 62/208. Loss of 0.7750, cover loss of 0.0024, secret loss of 0.7726
# Training: Batch 63/208. Loss of 1.0046, cover loss of 0.0029, secret loss of 1.0018
# Training: Batch 64/208. Loss of 0.5273, cover loss of 0.0018, secret loss of 0.5255
# Training: Batch 65/208. Loss of 1.3936, cover loss of 0.0012, secret loss of 1.3923
# Training: Batch 66/208. Loss of 0.9644, cover loss of 0.0022, secret loss of 0.9622
# Training: Batch 67/208. Loss of 0.7444, cover loss of 0.0022, secret loss of 0.7422
# Training: Batch 68/208. Loss of 0.4661, cover loss of 0.0017, secret loss of 0.4644
# Training: Batch 69/208. Loss of 1.5471, cover loss of 0.0026, secret loss of 1.5445
# Training: Batch 70/208. Loss of 0.4029, cover loss of 0.0021, secret loss of 0.4007
# Training: Batch 71/208. Loss of 1.6368, cover loss of 0.0020, secret loss of 1.6348
# Training: Batch 72/208. Loss of 1.6168, cover loss of 0.0016, secret loss of 1.6152
# Training: Batch 73/208. Loss of 1.1288, cover loss of 0.0019, secret loss of 1.1268
# Training: Batch 74/208. Loss of 0.9982, cover loss of 0.0026, secret loss of 0.9956
# Training: Batch 75/208. Loss of 1.9172, cover loss of 0.0012, secret loss of 1.9160
# Training: Batch 76/208. Loss of 0.9907, cover loss of 0.0019, secret loss of 0.9888
# Training: Batch 77/208. Loss of 0.3788, cover loss of 0.0031, secret loss of 0.3758
# Training: Batch 78/208. Loss of 0.4702, cover loss of 0.0013, secret loss of 0.4689
# Training: Batch 79/208. Loss of 0.6912, cover loss of 0.0034, secret loss of 0.6878
# Training: Batch 80/208. Loss of 1.0973, cover loss of 0.0017, secret loss of 1.0957
# Training: Batch 81/208. Loss of 0.8529, cover loss of 0.0027, secret loss of 0.8501
# Training: Batch 82/208. Loss of 1.1475, cover loss of 0.0032, secret loss of 1.1443
# Training: Batch 83/208. Loss of 0.9289, cover loss of 0.0042, secret loss of 0.9248
# Training: Batch 84/208. Loss of 0.7390, cover loss of 0.0039, secret loss of 0.7352
# Training: Batch 85/208. Loss of 0.4097, cover loss of 0.0017, secret loss of 0.4080
# Training: Batch 86/208. Loss of 1.9023, cover loss of 0.0036, secret loss of 1.8987
# Training: Batch 87/208. Loss of 1.4011, cover loss of 0.0025, secret loss of 1.3986
# Training: Batch 88/208. Loss of 1.0119, cover loss of 0.0027, secret loss of 1.0092
# Training: Batch 89/208. Loss of 0.6115, cover loss of 0.0061, secret loss of 0.6054
# Training: Batch 90/208. Loss of 0.9200, cover loss of 0.0028, secret loss of 0.9173
# Training: Batch 91/208. Loss of 1.4279, cover loss of 0.0013, secret loss of 1.4266
# Training: Batch 92/208. Loss of 0.8702, cover loss of 0.0012, secret loss of 0.8691
# Training: Batch 93/208. Loss of 1.0796, cover loss of 0.0016, secret loss of 1.0780
# Training: Batch 94/208. Loss of 0.7335, cover loss of 0.0019, secret loss of 0.7316
# Training: Batch 95/208. Loss of 0.6940, cover loss of 0.0034, secret loss of 0.6905
# Training: Batch 96/208. Loss of 1.4164, cover loss of 0.0038, secret loss of 1.4126
# Training: Batch 97/208. Loss of 1.3572, cover loss of 0.0024, secret loss of 1.3548
# Training: Batch 98/208. Loss of 1.4510, cover loss of 0.0048, secret loss of 1.4462
# Training: Batch 99/208. Loss of 0.8970, cover loss of 0.0036, secret loss of 0.8934
# Training: Batch 100/208. Loss of 1.1167, cover loss of 0.0061, secret loss of 1.1107
# Training: Batch 101/208. Loss of 1.2573, cover loss of 0.0022, secret loss of 1.2551
# Training: Batch 102/208. Loss of 0.6672, cover loss of 0.0028, secret loss of 0.6644
# Training: Batch 103/208. Loss of 0.6434, cover loss of 0.0033, secret loss of 0.6401
# Training: Batch 104/208. Loss of 0.8096, cover loss of 0.0020, secret loss of 0.8077
# Training: Batch 105/208. Loss of 1.0537, cover loss of 0.0064, secret loss of 1.0473
# Training: Batch 106/208. Loss of 1.5330, cover loss of 0.0013, secret loss of 1.5317
# Training: Batch 107/208. Loss of 0.6681, cover loss of 0.0044, secret loss of 0.6636
# Training: Batch 108/208. Loss of 1.1683, cover loss of 0.0034, secret loss of 1.1649
# Training: Batch 109/208. Loss of 1.9575, cover loss of 0.0023, secret loss of 1.9552
# Training: Batch 110/208. Loss of 1.0676, cover loss of 0.0031, secret loss of 1.0645
# Training: Batch 111/208. Loss of 0.3687, cover loss of 0.0089, secret loss of 0.3597
# Training: Batch 112/208. Loss of 3.0139, cover loss of 0.0032, secret loss of 3.0107
# Training: Batch 113/208. Loss of 0.7008, cover loss of 0.0035, secret loss of 0.6973
# Training: Batch 114/208. Loss of 1.4933, cover loss of 0.0020, secret loss of 1.4912
# Training: Batch 115/208. Loss of 0.4513, cover loss of 0.0025, secret loss of 0.4488
# Training: Batch 116/208. Loss of 0.3813, cover loss of 0.0032, secret loss of 0.3780
# Training: Batch 117/208. Loss of 0.8185, cover loss of 0.0022, secret loss of 0.8163
# Training: Batch 118/208. Loss of 0.7463, cover loss of 0.0037, secret loss of 0.7426
# Training: Batch 119/208. Loss of 1.7116, cover loss of 0.0020, secret loss of 1.7095
# Training: Batch 120/208. Loss of 0.9576, cover loss of 0.0037, secret loss of 0.9538
# Training: Batch 121/208. Loss of 1.1607, cover loss of 0.0068, secret loss of 1.1539
# Training: Batch 122/208. Loss of 2.3633, cover loss of 0.0048, secret loss of 2.3585
# Training: Batch 123/208. Loss of 1.2514, cover loss of 0.0062, secret loss of 1.2452
# Training: Batch 124/208. Loss of 1.6489, cover loss of 0.0049, secret loss of 1.6440
# Training: Batch 125/208. Loss of 0.7236, cover loss of 0.0073, secret loss of 0.7162
# Training: Batch 126/208. Loss of 0.5691, cover loss of 0.0117, secret loss of 0.5574
# Training: Batch 127/208. Loss of 0.4608, cover loss of 0.0054, secret loss of 0.4553
# Training: Batch 128/208. Loss of 1.8988, cover loss of 0.0049, secret loss of 1.8939
# Training: Batch 129/208. Loss of 0.7217, cover loss of 0.0058, secret loss of 0.7159
# Training: Batch 130/208. Loss of 1.9133, cover loss of 0.0077, secret loss of 1.9056
# Training: Batch 131/208. Loss of 1.1886, cover loss of 0.0061, secret loss of 1.1825
# Training: Batch 132/208. Loss of 0.9831, cover loss of 0.0066, secret loss of 0.9765
# Training: Batch 133/208. Loss of 0.4613, cover loss of 0.0065, secret loss of 0.4548
# Training: Batch 134/208. Loss of 0.8787, cover loss of 0.0018, secret loss of 0.8768
# Training: Batch 135/208. Loss of 1.7500, cover loss of 0.0055, secret loss of 1.7445
# Training: Batch 136/208. Loss of 0.5525, cover loss of 0.0079, secret loss of 0.5445
# Training: Batch 137/208. Loss of 1.3221, cover loss of 0.0045, secret loss of 1.3176
# Training: Batch 138/208. Loss of 1.4852, cover loss of 0.0039, secret loss of 1.4812
# Training: Batch 139/208. Loss of 2.5083, cover loss of 0.0129, secret loss of 2.4953
# Training: Batch 140/208. Loss of 0.8820, cover loss of 0.0048, secret loss of 0.8772
# Training: Batch 141/208. Loss of 0.4800, cover loss of 0.0081, secret loss of 0.4719
# Training: Batch 142/208. Loss of 1.1129, cover loss of 0.0050, secret loss of 1.1079
# Training: Batch 143/208. Loss of 1.1501, cover loss of 0.0028, secret loss of 1.1473
# Training: Batch 144/208. Loss of 0.6522, cover loss of 0.0050, secret loss of 0.6473
# Training: Batch 145/208. Loss of 0.6236, cover loss of 0.0033, secret loss of 0.6203
# Training: Batch 146/208. Loss of 0.7213, cover loss of 0.0021, secret loss of 0.7193
# Training: Batch 147/208. Loss of 1.3033, cover loss of 0.0041, secret loss of 1.2991
# Training: Batch 148/208. Loss of 0.6843, cover loss of 0.0058, secret loss of 0.6785
# Training: Batch 149/208. Loss of 1.2081, cover loss of 0.0015, secret loss of 1.2066
# Training: Batch 150/208. Loss of 1.2507, cover loss of 0.0058, secret loss of 1.2449
# Training: Batch 151/208. Loss of 1.0323, cover loss of 0.0038, secret loss of 1.0285
# Training: Batch 152/208. Loss of 0.7318, cover loss of 0.0066, secret loss of 0.7251
# Training: Batch 153/208. Loss of 1.6145, cover loss of 0.0031, secret loss of 1.6114
# Training: Batch 154/208. Loss of 1.3338, cover loss of 0.0041, secret loss of 1.3297
# Training: Batch 155/208. Loss of 0.4636, cover loss of 0.0049, secret loss of 0.4587
# Training: Batch 156/208. Loss of 1.2220, cover loss of 0.0031, secret loss of 1.2189
# Training: Batch 157/208. Loss of 0.8181, cover loss of 0.0028, secret loss of 0.8154
# Training: Batch 158/208. Loss of 0.5309, cover loss of 0.0018, secret loss of 0.5291
# Training: Batch 159/208. Loss of 0.8944, cover loss of 0.0025, secret loss of 0.8919
# Training: Batch 160/208. Loss of 0.4200, cover loss of 0.0033, secret loss of 0.4167
# Training: Batch 161/208. Loss of 2.0845, cover loss of 0.0028, secret loss of 2.0817
# Training: Batch 162/208. Loss of 0.6145, cover loss of 0.0041, secret loss of 0.6104
# Training: Batch 163/208. Loss of 0.8852, cover loss of 0.0023, secret loss of 0.8830
# Training: Batch 164/208. Loss of 1.1556, cover loss of 0.0025, secret loss of 1.1531
# Training: Batch 165/208. Loss of 0.4382, cover loss of 0.0018, secret loss of 0.4364
# Training: Batch 166/208. Loss of 0.6873, cover loss of 0.0013, secret loss of 0.6860
# Training: Batch 167/208. Loss of 1.3378, cover loss of 0.0045, secret loss of 1.3333
# Training: Batch 168/208. Loss of 0.4381, cover loss of 0.0031, secret loss of 0.4349
# Training: Batch 169/208. Loss of 0.9885, cover loss of 0.0325, secret loss of 0.9561
# Training: Batch 170/208. Loss of 3.0027, cover loss of 0.0070, secret loss of 2.9958
# Training: Batch 171/208. Loss of 0.9894, cover loss of 0.0121, secret loss of 0.9773
# Training: Batch 172/208. Loss of 1.5649, cover loss of 0.0198, secret loss of 1.5451
# Training: Batch 173/208. Loss of 0.6361, cover loss of 0.0057, secret loss of 0.6305
# Training: Batch 174/208. Loss of 0.8605, cover loss of 0.0065, secret loss of 0.8540
# Training: Batch 175/208. Loss of 1.1067, cover loss of 0.0048, secret loss of 1.1019
# Training: Batch 176/208. Loss of 0.2246, cover loss of 0.0022, secret loss of 0.2224
# Training: Batch 177/208. Loss of 1.3503, cover loss of 0.0207, secret loss of 1.3296
# Training: Batch 178/208. Loss of 1.0698, cover loss of 0.0043, secret loss of 1.0654
# Training: Batch 179/208. Loss of 0.6146, cover loss of 0.0231, secret loss of 0.5915
# Training: Batch 180/208. Loss of 0.8918, cover loss of 0.0074, secret loss of 0.8844
# Training: Batch 181/208. Loss of 0.4089, cover loss of 0.0038, secret loss of 0.4051
# Training: Batch 182/208. Loss of 1.6086, cover loss of 0.0071, secret loss of 1.6016
# Training: Batch 183/208. Loss of 0.6343, cover loss of 0.0037, secret loss of 0.6306
# Training: Batch 184/208. Loss of 1.5886, cover loss of 0.0036, secret loss of 1.5850
# Training: Batch 185/208. Loss of 2.0859, cover loss of 0.0086, secret loss of 2.0773
# Training: Batch 186/208. Loss of 1.1562, cover loss of 0.0073, secret loss of 1.1489
# Training: Batch 187/208. Loss of 0.9230, cover loss of 0.0091, secret loss of 0.9139
# Training: Batch 188/208. Loss of 0.6422, cover loss of 0.0052, secret loss of 0.6370
# Training: Batch 189/208. Loss of 0.7428, cover loss of 0.0050, secret loss of 0.7378
# Training: Batch 190/208. Loss of 1.0162, cover loss of 0.0083, secret loss of 1.0079
# Training: Batch 191/208. Loss of 1.7264, cover loss of 0.0059, secret loss of 1.7205
# Training: Batch 192/208. Loss of 0.4748, cover loss of 0.0055, secret loss of 0.4693
# Training: Batch 193/208. Loss of 1.0247, cover loss of 0.0044, secret loss of 1.0203
# Training: Batch 194/208. Loss of 1.7212, cover loss of 0.0032, secret loss of 1.7180
# Training: Batch 195/208. Loss of 0.5727, cover loss of 0.0073, secret loss of 0.5654
# Training: Batch 196/208. Loss of 0.7960, cover loss of 0.0092, secret loss of 0.7868
# Training: Batch 197/208. Loss of 0.8757, cover loss of 0.0092, secret loss of 0.8665
# Training: Batch 198/208. Loss of 0.9411, cover loss of 0.0030, secret loss of 0.9381
# Training: Batch 199/208. Loss of 0.8111, cover loss of 0.0025, secret loss of 0.8087
# Training: Batch 200/208. Loss of 0.4644, cover loss of 0.0046, secret loss of 0.4598
# Training: Batch 201/208. Loss of 0.3624, cover loss of 0.0098, secret loss of 0.3526
# Training: Batch 202/208. Loss of 1.2944, cover loss of 0.0053, secret loss of 1.2891
# Training: Batch 203/208. Loss of 0.8805, cover loss of 0.0070, secret loss of 0.8735
# Training: Batch 204/208. Loss of 1.1555, cover loss of 0.0041, secret loss of 1.1515
# Training: Batch 205/208. Loss of 0.8254, cover loss of 0.0061, secret loss of 0.8194
# Training: Batch 206/208. Loss of 2.0348, cover loss of 0.0035, secret loss of 2.0314
# Training: Batch 207/208. Loss of 0.4255, cover loss of 0.0073, secret loss of 0.4182
# Training: Batch 208/208. Loss of 0.3917, cover loss of 0.0029, secret loss of 0.3887
# Epoch [1/3], Average_loss: 1.0459
# Training: Batch 1/208. Loss of 0.8400, cover loss of 0.0038, secret loss of 0.8362
# Training: Batch 2/208. Loss of 0.6624, cover loss of 0.0022, secret loss of 0.6602
# Training: Batch 3/208. Loss of 1.0253, cover loss of 0.0051, secret loss of 1.0203
# Training: Batch 4/208. Loss of 0.3937, cover loss of 0.0044, secret loss of 0.3893
# Training: Batch 5/208. Loss of 1.0435, cover loss of 0.0041, secret loss of 1.0394
# Training: Batch 6/208. Loss of 0.8091, cover loss of 0.0085, secret loss of 0.8007
# Training: Batch 7/208. Loss of 0.9353, cover loss of 0.0031, secret loss of 0.9322
# Training: Batch 8/208. Loss of 0.9983, cover loss of 0.0019, secret loss of 0.9964
# Training: Batch 9/208. Loss of 0.7308, cover loss of 0.0045, secret loss of 0.7263
# Training: Batch 10/208. Loss of 1.1584, cover loss of 0.0053, secret loss of 1.1530
# Training: Batch 11/208. Loss of 0.7493, cover loss of 0.0082, secret loss of 0.7410
# Training: Batch 12/208. Loss of 1.6413, cover loss of 0.0038, secret loss of 1.6375
# Training: Batch 13/208. Loss of 1.0097, cover loss of 0.0016, secret loss of 1.0080
# Training: Batch 14/208. Loss of 2.5490, cover loss of 0.0022, secret loss of 2.5468
# Training: Batch 15/208. Loss of 1.1425, cover loss of 0.0021, secret loss of 1.1404
# Training: Batch 16/208. Loss of 1.0792, cover loss of 0.0036, secret loss of 1.0756
# Training: Batch 17/208. Loss of 0.9430, cover loss of 0.0063, secret loss of 0.9366
# Training: Batch 18/208. Loss of 1.3605, cover loss of 0.0027, secret loss of 1.3577
# Training: Batch 19/208. Loss of 3.0028, cover loss of 0.0055, secret loss of 2.9973
# Training: Batch 20/208. Loss of 1.1124, cover loss of 0.0025, secret loss of 1.1099
# Training: Batch 21/208. Loss of 0.9163, cover loss of 0.0033, secret loss of 0.9130
# Training: Batch 22/208. Loss of 0.8709, cover loss of 0.0019, secret loss of 0.8690
# Training: Batch 23/208. Loss of 0.2180, cover loss of 0.0048, secret loss of 0.2132
# Training: Batch 24/208. Loss of 0.3263, cover loss of 0.0014, secret loss of 0.3249
# Training: Batch 25/208. Loss of 0.3952, cover loss of 0.0032, secret loss of 0.3920
# Training: Batch 26/208. Loss of 0.8007, cover loss of 0.0037, secret loss of 0.7970
# Training: Batch 27/208. Loss of 0.6359, cover loss of 0.0044, secret loss of 0.6315
# Training: Batch 28/208. Loss of 1.3857, cover loss of 0.0021, secret loss of 1.3836
# Training: Batch 29/208. Loss of 0.7036, cover loss of 0.0018, secret loss of 0.7018
# Training: Batch 30/208. Loss of 0.4777, cover loss of 0.0022, secret loss of 0.4755
# Training: Batch 31/208. Loss of 1.8963, cover loss of 0.0024, secret loss of 1.8939
# Training: Batch 32/208. Loss of 0.6650, cover loss of 0.0022, secret loss of 0.6627
# Training: Batch 33/208. Loss of 0.8786, cover loss of 0.0027, secret loss of 0.8759
# Training: Batch 34/208. Loss of 1.3075, cover loss of 0.0043, secret loss of 1.3032
# Training: Batch 35/208. Loss of 0.3727, cover loss of 0.0037, secret loss of 0.3690
# Training: Batch 36/208. Loss of 1.2499, cover loss of 0.0069, secret loss of 1.2430
# Training: Batch 37/208. Loss of 1.0880, cover loss of 0.0045, secret loss of 1.0836
# Training: Batch 38/208. Loss of 1.1529, cover loss of 0.0024, secret loss of 1.1505
# Training: Batch 39/208. Loss of 1.3495, cover loss of 0.0059, secret loss of 1.3436
# Training: Batch 40/208. Loss of 1.3634, cover loss of 0.0036, secret loss of 1.3598
# Training: Batch 41/208. Loss of 0.6411, cover loss of 0.0027, secret loss of 0.6383
# Training: Batch 42/208. Loss of 1.2668, cover loss of 0.0028, secret loss of 1.2640
# Training: Batch 43/208. Loss of 0.7252, cover loss of 0.0024, secret loss of 0.7228
# Training: Batch 44/208. Loss of 0.9873, cover loss of 0.0074, secret loss of 0.9799
# Training: Batch 45/208. Loss of 1.3361, cover loss of 0.0017, secret loss of 1.3344
# Training: Batch 46/208. Loss of 2.4144, cover loss of 0.0068, secret loss of 2.4075
# Training: Batch 47/208. Loss of 0.8335, cover loss of 0.0041, secret loss of 0.8294
# Training: Batch 48/208. Loss of 1.6150, cover loss of 0.0060, secret loss of 1.6090
# Training: Batch 49/208. Loss of 0.4520, cover loss of 0.0041, secret loss of 0.4479
# Training: Batch 50/208. Loss of 1.0951, cover loss of 0.0025, secret loss of 1.0926
# Training: Batch 51/208. Loss of 0.9203, cover loss of 0.0034, secret loss of 0.9169
# Training: Batch 52/208. Loss of 1.1256, cover loss of 0.0022, secret loss of 1.1234
# Training: Batch 53/208. Loss of 0.2947, cover loss of 0.0021, secret loss of 0.2927
# Training: Batch 54/208. Loss of 0.4688, cover loss of 0.0020, secret loss of 0.4668
# Training: Batch 55/208. Loss of 2.4124, cover loss of 0.0032, secret loss of 2.4092
# Training: Batch 56/208. Loss of 0.5439, cover loss of 0.0047, secret loss of 0.5391
# Training: Batch 57/208. Loss of 1.3027, cover loss of 0.0044, secret loss of 1.2983
# Training: Batch 58/208. Loss of 1.3133, cover loss of 0.0079, secret loss of 1.3054
# Training: Batch 59/208. Loss of 0.7448, cover loss of 0.0030, secret loss of 0.7418
# Training: Batch 60/208. Loss of 0.9687, cover loss of 0.0046, secret loss of 0.9641
# Training: Batch 61/208. Loss of 0.6403, cover loss of 0.0134, secret loss of 0.6269
# Training: Batch 62/208. Loss of 0.8550, cover loss of 0.0036, secret loss of 0.8515
# Training: Batch 63/208. Loss of 1.0667, cover loss of 0.0016, secret loss of 1.0651
# Training: Batch 64/208. Loss of 1.1037, cover loss of 0.0023, secret loss of 1.1014
# Training: Batch 65/208. Loss of 2.3115, cover loss of 0.0199, secret loss of 2.2916
# Training: Batch 66/208. Loss of 1.1478, cover loss of 0.0035, secret loss of 1.1443
# Training: Batch 67/208. Loss of 1.3586, cover loss of 0.0071, secret loss of 1.3515
# Training: Batch 68/208. Loss of 1.1623, cover loss of 0.0089, secret loss of 1.1533
# Training: Batch 69/208. Loss of 0.7225, cover loss of 0.0060, secret loss of 0.7165
# Training: Batch 70/208. Loss of 1.3046, cover loss of 0.0078, secret loss of 1.2968
# Training: Batch 71/208. Loss of 0.7259, cover loss of 0.0042, secret loss of 0.7218
# Training: Batch 72/208. Loss of 0.3151, cover loss of 0.0094, secret loss of 0.3058
# Training: Batch 73/208. Loss of 1.2758, cover loss of 0.0054, secret loss of 1.2705
# Training: Batch 74/208. Loss of 1.5847, cover loss of 0.0156, secret loss of 1.5691
# Training: Batch 75/208. Loss of 0.5111, cover loss of 0.0056, secret loss of 0.5055
# Training: Batch 76/208. Loss of 0.6171, cover loss of 0.0069, secret loss of 0.6102
# Training: Batch 77/208. Loss of 1.4774, cover loss of 0.0234, secret loss of 1.4540
# Training: Batch 78/208. Loss of 0.8274, cover loss of 0.0091, secret loss of 0.8183
# Training: Batch 79/208. Loss of 1.7342, cover loss of 0.0044, secret loss of 1.7298
# Training: Batch 80/208. Loss of 0.6817, cover loss of 0.0085, secret loss of 0.6732
# Training: Batch 81/208. Loss of 1.1171, cover loss of 0.0053, secret loss of 1.1118
# Training: Batch 82/208. Loss of 0.6904, cover loss of 0.0057, secret loss of 0.6848
# Training: Batch 83/208. Loss of 0.7830, cover loss of 0.0034, secret loss of 0.7796
# Training: Batch 84/208. Loss of 1.8820, cover loss of 0.0283, secret loss of 1.8536
# Training: Batch 85/208. Loss of 1.0513, cover loss of 0.0051, secret loss of 1.0463
# Training: Batch 86/208. Loss of 1.4501, cover loss of 0.0057, secret loss of 1.4444
# Training: Batch 87/208. Loss of 0.5825, cover loss of 0.0057, secret loss of 0.5767
# Training: Batch 88/208. Loss of 1.5890, cover loss of 0.0159, secret loss of 1.5731
# Training: Batch 89/208. Loss of 0.7007, cover loss of 0.0022, secret loss of 0.6985
# Training: Batch 90/208. Loss of 1.3632, cover loss of 0.0030, secret loss of 1.3602
# Training: Batch 91/208. Loss of 0.4864, cover loss of 0.0033, secret loss of 0.4831
# Training: Batch 92/208. Loss of 0.9076, cover loss of 0.0044, secret loss of 0.9032
# Training: Batch 93/208. Loss of 1.6999, cover loss of 0.0045, secret loss of 1.6954
# Training: Batch 94/208. Loss of 0.3406, cover loss of 0.0042, secret loss of 0.3364
# Training: Batch 95/208. Loss of 1.0839, cover loss of 0.0147, secret loss of 1.0693
# Training: Batch 96/208. Loss of 1.0336, cover loss of 0.0021, secret loss of 1.0315
# Training: Batch 97/208. Loss of 1.0465, cover loss of 0.0187, secret loss of 1.0278
# Training: Batch 98/208. Loss of 1.1450, cover loss of 0.0075, secret loss of 1.1376
# Training: Batch 99/208. Loss of 0.4905, cover loss of 0.0206, secret loss of 0.4699
# Training: Batch 100/208. Loss of 0.3897, cover loss of 0.0060, secret loss of 0.3836
# Training: Batch 101/208. Loss of 1.3243, cover loss of 0.0030, secret loss of 1.3213
# Training: Batch 102/208. Loss of 0.4180, cover loss of 0.0024, secret loss of 0.4155
# Training: Batch 103/208. Loss of 1.4181, cover loss of 0.0058, secret loss of 1.4124
# Training: Batch 104/208. Loss of 1.1502, cover loss of 0.0055, secret loss of 1.1447
# Training: Batch 105/208. Loss of 1.4286, cover loss of 0.0081, secret loss of 1.4205
# Training: Batch 106/208. Loss of 1.2078, cover loss of 0.0045, secret loss of 1.2033
# Training: Batch 107/208. Loss of 1.4765, cover loss of 0.0024, secret loss of 1.4741
# Training: Batch 108/208. Loss of 0.9993, cover loss of 0.0035, secret loss of 0.9958
# Training: Batch 109/208. Loss of 0.3280, cover loss of 0.0070, secret loss of 0.3209
# Training: Batch 110/208. Loss of 0.4050, cover loss of 0.0068, secret loss of 0.3982
# Training: Batch 111/208. Loss of 0.9871, cover loss of 0.0062, secret loss of 0.9809
# Training: Batch 112/208. Loss of 1.2734, cover loss of 0.0027, secret loss of 1.2707
# Training: Batch 113/208. Loss of 0.8667, cover loss of 0.0059, secret loss of 0.8609
# Training: Batch 114/208. Loss of 0.4406, cover loss of 0.0050, secret loss of 0.4355
# Training: Batch 115/208. Loss of 0.5336, cover loss of 0.0035, secret loss of 0.5301
# Training: Batch 116/208. Loss of 0.4449, cover loss of 0.0486, secret loss of 0.3963
# Training: Batch 117/208. Loss of 0.8621, cover loss of 0.0105, secret loss of 0.8515
# Training: Batch 118/208. Loss of 1.6920, cover loss of 0.0127, secret loss of 1.6793
# Training: Batch 119/208. Loss of 1.0945, cover loss of 0.0351, secret loss of 1.0594
# Training: Batch 120/208. Loss of 0.7084, cover loss of 0.0053, secret loss of 0.7030
# Training: Batch 121/208. Loss of 0.7801, cover loss of 0.0077, secret loss of 0.7724
# Training: Batch 122/208. Loss of 0.7510, cover loss of 0.0241, secret loss of 0.7268
# Training: Batch 123/208. Loss of 0.7949, cover loss of 0.0104, secret loss of 0.7845
# Training: Batch 124/208. Loss of 0.4951, cover loss of 0.0225, secret loss of 0.4726
# Training: Batch 125/208. Loss of 0.7682, cover loss of 0.0087, secret loss of 0.7595
# Training: Batch 126/208. Loss of 1.0558, cover loss of 0.0073, secret loss of 1.0485
# Training: Batch 127/208. Loss of 1.1802, cover loss of 0.0054, secret loss of 1.1748
# Training: Batch 128/208. Loss of 1.4038, cover loss of 0.0045, secret loss of 1.3992
# Training: Batch 129/208. Loss of 1.2966, cover loss of 0.0078, secret loss of 1.2889
# Training: Batch 130/208. Loss of 1.3682, cover loss of 0.0043, secret loss of 1.3639
# Training: Batch 131/208. Loss of 1.3554, cover loss of 0.0062, secret loss of 1.3492
# Training: Batch 132/208. Loss of 1.2516, cover loss of 0.0051, secret loss of 1.2465
# Training: Batch 133/208. Loss of 0.6716, cover loss of 0.0053, secret loss of 0.6662
# Training: Batch 134/208. Loss of 1.1560, cover loss of 0.0042, secret loss of 1.1517
# Training: Batch 135/208. Loss of 2.2201, cover loss of 0.0045, secret loss of 2.2156
# Training: Batch 136/208. Loss of 0.6487, cover loss of 0.0071, secret loss of 0.6416
# Training: Batch 137/208. Loss of 0.7364, cover loss of 0.0044, secret loss of 0.7319
# Training: Batch 138/208. Loss of 0.6439, cover loss of 0.0054, secret loss of 0.6385
# Training: Batch 139/208. Loss of 1.4490, cover loss of 0.0076, secret loss of 1.4414
# Training: Batch 140/208. Loss of 1.1625, cover loss of 0.0076, secret loss of 1.1549
# Training: Batch 141/208. Loss of 1.2469, cover loss of 0.0056, secret loss of 1.2413
# Training: Batch 142/208. Loss of 1.0215, cover loss of 0.0038, secret loss of 1.0177
# Training: Batch 143/208. Loss of 0.4302, cover loss of 0.0019, secret loss of 0.4283
# Training: Batch 144/208. Loss of 0.6328, cover loss of 0.0018, secret loss of 0.6311
# Training: Batch 145/208. Loss of 0.8004, cover loss of 0.0089, secret loss of 0.7915
# Training: Batch 146/208. Loss of 1.0618, cover loss of 0.0023, secret loss of 1.0595
# Training: Batch 147/208. Loss of 0.8950, cover loss of 0.0017, secret loss of 0.8933
# Training: Batch 148/208. Loss of 0.6216, cover loss of 0.0026, secret loss of 0.6190
# Training: Batch 149/208. Loss of 0.7583, cover loss of 0.0027, secret loss of 0.7556
# Training: Batch 150/208. Loss of 1.9049, cover loss of 0.0059, secret loss of 1.8990
# Training: Batch 151/208. Loss of 0.2832, cover loss of 0.0041, secret loss of 0.2792
# Training: Batch 152/208. Loss of 0.8404, cover loss of 0.0026, secret loss of 0.8378
# Training: Batch 153/208. Loss of 1.2764, cover loss of 0.0043, secret loss of 1.2721
# Training: Batch 154/208. Loss of 0.9993, cover loss of 0.0027, secret loss of 0.9966
# Training: Batch 155/208. Loss of 0.5695, cover loss of 0.0022, secret loss of 0.5673
# Training: Batch 156/208. Loss of 0.8054, cover loss of 0.0048, secret loss of 0.8005
# Training: Batch 157/208. Loss of 0.9387, cover loss of 0.0017, secret loss of 0.9369
# Training: Batch 158/208. Loss of 0.4239, cover loss of 0.0083, secret loss of 0.4156
# Training: Batch 159/208. Loss of 0.6235, cover loss of 0.0023, secret loss of 0.6212
# Training: Batch 160/208. Loss of 1.6445, cover loss of 0.0020, secret loss of 1.6424
# Training: Batch 161/208. Loss of 1.4686, cover loss of 0.0017, secret loss of 1.4669
# Training: Batch 162/208. Loss of 1.0130, cover loss of 0.0080, secret loss of 1.0050
# Training: Batch 163/208. Loss of 0.7125, cover loss of 0.0030, secret loss of 0.7095
# Training: Batch 164/208. Loss of 0.5417, cover loss of 0.0040, secret loss of 0.5377
# Training: Batch 165/208. Loss of 0.7918, cover loss of 0.0014, secret loss of 0.7904
# Training: Batch 166/208. Loss of 1.2048, cover loss of 0.0074, secret loss of 1.1974
# Training: Batch 167/208. Loss of 0.6138, cover loss of 0.0022, secret loss of 0.6116
# Training: Batch 168/208. Loss of 1.4665, cover loss of 0.0022, secret loss of 1.4643
# Training: Batch 169/208. Loss of 0.9184, cover loss of 0.0032, secret loss of 0.9151
# Training: Batch 170/208. Loss of 1.0024, cover loss of 0.0017, secret loss of 1.0007
# Training: Batch 171/208. Loss of 1.7176, cover loss of 0.0021, secret loss of 1.7155
# Training: Batch 172/208. Loss of 0.9965, cover loss of 0.0050, secret loss of 0.9915
# Training: Batch 173/208. Loss of 0.4086, cover loss of 0.0034, secret loss of 0.4052
# Training: Batch 174/208. Loss of 1.4092, cover loss of 0.0017, secret loss of 1.4075
# Training: Batch 175/208. Loss of 0.5279, cover loss of 0.0028, secret loss of 0.5251
# Training: Batch 176/208. Loss of 1.0453, cover loss of 0.0020, secret loss of 1.0434
# Training: Batch 177/208. Loss of 0.7519, cover loss of 0.0031, secret loss of 0.7488
# Training: Batch 178/208. Loss of 0.4861, cover loss of 0.0025, secret loss of 0.4836
# Training: Batch 179/208. Loss of 0.7945, cover loss of 0.0040, secret loss of 0.7905
# Training: Batch 180/208. Loss of 0.7755, cover loss of 0.0058, secret loss of 0.7697
# Training: Batch 181/208. Loss of 0.1786, cover loss of 0.0028, secret loss of 0.1758
# Training: Batch 182/208. Loss of 0.9405, cover loss of 0.0038, secret loss of 0.9367
# Training: Batch 183/208. Loss of 1.0516, cover loss of 0.0029, secret loss of 1.0486
# Training: Batch 184/208. Loss of 0.8241, cover loss of 0.0034, secret loss of 0.8207
# Training: Batch 185/208. Loss of 0.7215, cover loss of 0.0033, secret loss of 0.7182
# Training: Batch 186/208. Loss of 0.6199, cover loss of 0.0021, secret loss of 0.6177
# Training: Batch 187/208. Loss of 0.8907, cover loss of 0.0016, secret loss of 0.8891
# Training: Batch 188/208. Loss of 1.0028, cover loss of 0.0053, secret loss of 0.9975
# Training: Batch 189/208. Loss of 2.1718, cover loss of 0.0047, secret loss of 2.1670
# Training: Batch 190/208. Loss of 0.7068, cover loss of 0.0018, secret loss of 0.7051
# Training: Batch 191/208. Loss of 0.8500, cover loss of 0.0023, secret loss of 0.8477
# Training: Batch 192/208. Loss of 0.9299, cover loss of 0.0020, secret loss of 0.9279
# Training: Batch 193/208. Loss of 1.8209, cover loss of 0.0012, secret loss of 1.8197
# Training: Batch 194/208. Loss of 0.4558, cover loss of 0.0021, secret loss of 0.4536
# Training: Batch 195/208. Loss of 1.7562, cover loss of 0.0012, secret loss of 1.7551
# Training: Batch 196/208. Loss of 0.4964, cover loss of 0.0012, secret loss of 0.4951
# Training: Batch 197/208. Loss of 1.0392, cover loss of 0.0023, secret loss of 1.0369
# Training: Batch 198/208. Loss of 0.5223, cover loss of 0.0027, secret loss of 0.5196
# Training: Batch 199/208. Loss of 0.8699, cover loss of 0.0015, secret loss of 0.8683
# Training: Batch 200/208. Loss of 0.4569, cover loss of 0.0046, secret loss of 0.4524
# Training: Batch 201/208. Loss of 0.4749, cover loss of 0.0029, secret loss of 0.4720
# Training: Batch 202/208. Loss of 1.1078, cover loss of 0.0015, secret loss of 1.1063
# Training: Batch 203/208. Loss of 0.4484, cover loss of 0.0015, secret loss of 0.4469
# Training: Batch 204/208. Loss of 0.6322, cover loss of 0.0045, secret loss of 0.6276
# Training: Batch 205/208. Loss of 1.2243, cover loss of 0.0015, secret loss of 1.2229
# Training: Batch 206/208. Loss of 0.9171, cover loss of 0.0005, secret loss of 0.9166
# Training: Batch 207/208. Loss of 1.0142, cover loss of 0.0019, secret loss of 1.0123
# Training: Batch 208/208. Loss of 0.6953, cover loss of 0.0033, secret loss of 0.6919
# Epoch [2/3], Average_loss: 0.9877
# Training: Batch 1/208. Loss of 0.7054, cover loss of 0.0015, secret loss of 0.7040
# Training: Batch 2/208. Loss of 1.5571, cover loss of 0.0021, secret loss of 1.5550
# Training: Batch 3/208. Loss of 1.5430, cover loss of 0.0010, secret loss of 1.5419
# Training: Batch 4/208. Loss of 1.0799, cover loss of 0.0018, secret loss of 1.0781
# Training: Batch 5/208. Loss of 0.3473, cover loss of 0.0019, secret loss of 0.3454
# Training: Batch 6/208. Loss of 0.7086, cover loss of 0.0018, secret loss of 0.7068
# Training: Batch 7/208. Loss of 0.2844, cover loss of 0.0018, secret loss of 0.2826
# Training: Batch 8/208. Loss of 0.7427, cover loss of 0.0022, secret loss of 0.7404
# Training: Batch 9/208. Loss of 0.8348, cover loss of 0.0028, secret loss of 0.8320
# Training: Batch 10/208. Loss of 1.1491, cover loss of 0.0016, secret loss of 1.1475
# Training: Batch 11/208. Loss of 1.1868, cover loss of 0.0018, secret loss of 1.1850
# Training: Batch 12/208. Loss of 2.6772, cover loss of 0.0013, secret loss of 2.6760
# Training: Batch 13/208. Loss of 0.3042, cover loss of 0.0046, secret loss of 0.2996
# Training: Batch 14/208. Loss of 0.7005, cover loss of 0.0010, secret loss of 0.6995
# Training: Batch 15/208. Loss of 0.3029, cover loss of 0.0021, secret loss of 0.3008
# Training: Batch 16/208. Loss of 0.9148, cover loss of 0.0009, secret loss of 0.9139
# Training: Batch 17/208. Loss of 1.2764, cover loss of 0.0025, secret loss of 1.2739
# Training: Batch 18/208. Loss of 0.5837, cover loss of 0.0033, secret loss of 0.5805
# Training: Batch 19/208. Loss of 0.3833, cover loss of 0.0015, secret loss of 0.3817
# Training: Batch 20/208. Loss of 1.8163, cover loss of 0.0014, secret loss of 1.8149
# Training: Batch 21/208. Loss of 0.6445, cover loss of 0.0019, secret loss of 0.6426
# Training: Batch 22/208. Loss of 0.7480, cover loss of 0.0007, secret loss of 0.7473
# Training: Batch 23/208. Loss of 0.4661, cover loss of 0.0007, secret loss of 0.4654
# Training: Batch 24/208. Loss of 1.7208, cover loss of 0.0016, secret loss of 1.7192
# Training: Batch 25/208. Loss of 2.9552, cover loss of 0.0020, secret loss of 2.9532
# Training: Batch 26/208. Loss of 0.9464, cover loss of 0.0006, secret loss of 0.9458
# Training: Batch 27/208. Loss of 0.6434, cover loss of 0.0008, secret loss of 0.6426
# Training: Batch 28/208. Loss of 2.5543, cover loss of 0.0023, secret loss of 2.5520
# Training: Batch 29/208. Loss of 0.7396, cover loss of 0.0016, secret loss of 0.7379
# Training: Batch 30/208. Loss of 0.8231, cover loss of 0.0008, secret loss of 0.8223
# Training: Batch 31/208. Loss of 0.6643, cover loss of 0.0021, secret loss of 0.6622
# Training: Batch 32/208. Loss of 0.7514, cover loss of 0.0010, secret loss of 0.7504
# Training: Batch 33/208. Loss of 0.7551, cover loss of 0.0012, secret loss of 0.7539
# Training: Batch 34/208. Loss of 0.8027, cover loss of 0.0013, secret loss of 0.8014
# Training: Batch 35/208. Loss of 0.7442, cover loss of 0.0013, secret loss of 0.7429
# Training: Batch 36/208. Loss of 1.6124, cover loss of 0.0008, secret loss of 1.6116
# Training: Batch 37/208. Loss of 1.0451, cover loss of 0.0011, secret loss of 1.0440
# Training: Batch 38/208. Loss of 0.8195, cover loss of 0.0014, secret loss of 0.8182
# Training: Batch 39/208. Loss of 0.8231, cover loss of 0.0008, secret loss of 0.8223
# Training: Batch 40/208. Loss of 0.5755, cover loss of 0.0011, secret loss of 0.5744
# Training: Batch 41/208. Loss of 0.9738, cover loss of 0.0007, secret loss of 0.9731
# Training: Batch 42/208. Loss of 0.6914, cover loss of 0.0011, secret loss of 0.6903
# Training: Batch 43/208. Loss of 0.6582, cover loss of 0.0018, secret loss of 0.6564
# Training: Batch 44/208. Loss of 0.9606, cover loss of 0.0013, secret loss of 0.9593
# Training: Batch 45/208. Loss of 1.4062, cover loss of 0.0011, secret loss of 1.4051
# Training: Batch 46/208. Loss of 0.7279, cover loss of 0.0018, secret loss of 0.7261
# Training: Batch 47/208. Loss of 1.8805, cover loss of 0.0007, secret loss of 1.8797
# Training: Batch 48/208. Loss of 0.7510, cover loss of 0.0013, secret loss of 0.7496
# Training: Batch 49/208. Loss of 0.7303, cover loss of 0.0019, secret loss of 0.7284
# Training: Batch 50/208. Loss of 1.4826, cover loss of 0.0015, secret loss of 1.4811
# Training: Batch 51/208. Loss of 0.8830, cover loss of 0.0011, secret loss of 0.8819
# Training: Batch 52/208. Loss of 0.7911, cover loss of 0.0022, secret loss of 0.7889
# Training: Batch 53/208. Loss of 0.6943, cover loss of 0.0021, secret loss of 0.6922
# Training: Batch 54/208. Loss of 0.3830, cover loss of 0.0012, secret loss of 0.3818
# Training: Batch 55/208. Loss of 0.9870, cover loss of 0.0013, secret loss of 0.9857
# Training: Batch 56/208. Loss of 0.4654, cover loss of 0.0011, secret loss of 0.4643
# Training: Batch 57/208. Loss of 1.8514, cover loss of 0.0008, secret loss of 1.8506
# Training: Batch 58/208. Loss of 0.7063, cover loss of 0.0012, secret loss of 0.7051
# Training: Batch 59/208. Loss of 0.3466, cover loss of 0.0010, secret loss of 0.3456
# Training: Batch 60/208. Loss of 1.6722, cover loss of 0.0007, secret loss of 1.6715
# Training: Batch 61/208. Loss of 1.1274, cover loss of 0.0010, secret loss of 1.1264
# Training: Batch 62/208. Loss of 1.0786, cover loss of 0.0007, secret loss of 1.0779
# Training: Batch 63/208. Loss of 0.4120, cover loss of 0.0014, secret loss of 0.4106
# Training: Batch 64/208. Loss of 0.4494, cover loss of 0.0013, secret loss of 0.4480
# Training: Batch 65/208. Loss of 1.9647, cover loss of 0.0022, secret loss of 1.9625
# Training: Batch 66/208. Loss of 0.8029, cover loss of 0.0014, secret loss of 0.8016
# Training: Batch 67/208. Loss of 0.8363, cover loss of 0.0009, secret loss of 0.8354
# Training: Batch 68/208. Loss of 0.3267, cover loss of 0.0005, secret loss of 0.3262
# Training: Batch 69/208. Loss of 1.5251, cover loss of 0.0010, secret loss of 1.5242
# Training: Batch 70/208. Loss of 1.3255, cover loss of 0.0015, secret loss of 1.3240
# Training: Batch 71/208. Loss of 0.4893, cover loss of 0.0011, secret loss of 0.4882
# Training: Batch 72/208. Loss of 1.4735, cover loss of 0.0017, secret loss of 1.4718
# Training: Batch 73/208. Loss of 0.4054, cover loss of 0.0009, secret loss of 0.4044
# Training: Batch 74/208. Loss of 0.6066, cover loss of 0.0019, secret loss of 0.6047
# Training: Batch 75/208. Loss of 0.6827, cover loss of 0.0011, secret loss of 0.6816
# Training: Batch 76/208. Loss of 0.4431, cover loss of 0.0010, secret loss of 0.4421
# Training: Batch 77/208. Loss of 1.1784, cover loss of 0.0010, secret loss of 1.1774
# Training: Batch 78/208. Loss of 0.8503, cover loss of 0.0013, secret loss of 0.8490
# Training: Batch 79/208. Loss of 1.3301, cover loss of 0.0005, secret loss of 1.3296
# Training: Batch 80/208. Loss of 3.1604, cover loss of 0.0011, secret loss of 3.1593
# Training: Batch 81/208. Loss of 1.4074, cover loss of 0.0008, secret loss of 1.4066
# Training: Batch 82/208. Loss of 1.1173, cover loss of 0.0018, secret loss of 1.1155
# Training: Batch 83/208. Loss of 0.7672, cover loss of 0.0008, secret loss of 0.7664
# Training: Batch 84/208. Loss of 0.6176, cover loss of 0.0017, secret loss of 0.6159
# Training: Batch 85/208. Loss of 1.7435, cover loss of 0.0010, secret loss of 1.7425
# Training: Batch 86/208. Loss of 0.7164, cover loss of 0.0029, secret loss of 0.7135
# Training: Batch 87/208. Loss of 1.2603, cover loss of 0.0010, secret loss of 1.2593
# Training: Batch 88/208. Loss of 0.6398, cover loss of 0.0008, secret loss of 0.6390
# Training: Batch 89/208. Loss of 0.3710, cover loss of 0.0008, secret loss of 0.3702
# Training: Batch 90/208. Loss of 0.4737, cover loss of 0.0007, secret loss of 0.4730
# Training: Batch 91/208. Loss of 0.5568, cover loss of 0.0009, secret loss of 0.5558
# Training: Batch 92/208. Loss of 0.3621, cover loss of 0.0008, secret loss of 0.3612
# Training: Batch 93/208. Loss of 0.7345, cover loss of 0.0030, secret loss of 0.7315
# Training: Batch 94/208. Loss of 0.6907, cover loss of 0.0009, secret loss of 0.6898
# Training: Batch 95/208. Loss of 0.7119, cover loss of 0.0014, secret loss of 0.7104
# Training: Batch 96/208. Loss of 1.1364, cover loss of 0.0012, secret loss of 1.1353
# Training: Batch 97/208. Loss of 2.2223, cover loss of 0.0014, secret loss of 2.2209
# Training: Batch 98/208. Loss of 1.8238, cover loss of 0.0022, secret loss of 1.8215
# Training: Batch 99/208. Loss of 0.4095, cover loss of 0.0009, secret loss of 0.4086
# Training: Batch 100/208. Loss of 0.6268, cover loss of 0.0015, secret loss of 0.6252
# Training: Batch 101/208. Loss of 0.6364, cover loss of 0.0017, secret loss of 0.6347
# Training: Batch 102/208. Loss of 0.7922, cover loss of 0.0013, secret loss of 0.7909
# Training: Batch 103/208. Loss of 0.3180, cover loss of 0.0021, secret loss of 0.3159
# Training: Batch 104/208. Loss of 0.7421, cover loss of 0.0020, secret loss of 0.7402
# Training: Batch 105/208. Loss of 1.2479, cover loss of 0.0012, secret loss of 1.2467
# Training: Batch 106/208. Loss of 1.2257, cover loss of 0.0020, secret loss of 1.2237
# Training: Batch 107/208. Loss of 0.5909, cover loss of 0.0012, secret loss of 0.5896
# Training: Batch 108/208. Loss of 1.2804, cover loss of 0.0009, secret loss of 1.2796
# Training: Batch 109/208. Loss of 1.1394, cover loss of 0.0046, secret loss of 1.1347
# Training: Batch 110/208. Loss of 0.5003, cover loss of 0.0017, secret loss of 0.4987
# Training: Batch 111/208. Loss of 0.3733, cover loss of 0.0013, secret loss of 0.3720
# Training: Batch 112/208. Loss of 0.4823, cover loss of 0.0025, secret loss of 0.4798
# Training: Batch 113/208. Loss of 1.6407, cover loss of 0.0040, secret loss of 1.6368
# Training: Batch 114/208. Loss of 0.8565, cover loss of 0.0030, secret loss of 0.8536
# Training: Batch 115/208. Loss of 1.1044, cover loss of 0.0035, secret loss of 1.1010
# Training: Batch 116/208. Loss of 1.0102, cover loss of 0.0049, secret loss of 1.0052
# Training: Batch 117/208. Loss of 1.0046, cover loss of 0.0010, secret loss of 1.0036
# Training: Batch 118/208. Loss of 0.8013, cover loss of 0.0027, secret loss of 0.7986
# Training: Batch 119/208. Loss of 1.7367, cover loss of 0.0026, secret loss of 1.7342
# Training: Batch 120/208. Loss of 2.0137, cover loss of 0.0023, secret loss of 2.0113
# Training: Batch 121/208. Loss of 1.4457, cover loss of 0.0020, secret loss of 1.4437
# Training: Batch 122/208. Loss of 1.0918, cover loss of 0.0024, secret loss of 1.0895
# Training: Batch 123/208. Loss of 1.6777, cover loss of 0.0023, secret loss of 1.6754
# Training: Batch 124/208. Loss of 1.3079, cover loss of 0.0021, secret loss of 1.3058
# Training: Batch 125/208. Loss of 0.8809, cover loss of 0.0020, secret loss of 0.8789
# Training: Batch 126/208. Loss of 0.8882, cover loss of 0.0018, secret loss of 0.8864
# Training: Batch 127/208. Loss of 1.4445, cover loss of 0.0029, secret loss of 1.4416
# Training: Batch 128/208. Loss of 0.4491, cover loss of 0.0031, secret loss of 0.4460
# Training: Batch 129/208. Loss of 1.1544, cover loss of 0.0017, secret loss of 1.1527
# Training: Batch 130/208. Loss of 0.9028, cover loss of 0.0017, secret loss of 0.9012
# Training: Batch 131/208. Loss of 1.1054, cover loss of 0.0030, secret loss of 1.1024
# Training: Batch 132/208. Loss of 0.5388, cover loss of 0.0024, secret loss of 0.5364
# Training: Batch 133/208. Loss of 1.1493, cover loss of 0.0027, secret loss of 1.1465
# Training: Batch 134/208. Loss of 1.2801, cover loss of 0.0065, secret loss of 1.2736
# Training: Batch 135/208. Loss of 0.5889, cover loss of 0.0019, secret loss of 0.5869
# Training: Batch 136/208. Loss of 1.0644, cover loss of 0.0016, secret loss of 1.0628
# Training: Batch 137/208. Loss of 1.1656, cover loss of 0.0035, secret loss of 1.1621
# Training: Batch 138/208. Loss of 0.9058, cover loss of 0.0059, secret loss of 0.9000
# Training: Batch 139/208. Loss of 1.4153, cover loss of 0.0026, secret loss of 1.4127
# Training: Batch 140/208. Loss of 1.4345, cover loss of 0.0066, secret loss of 1.4279
# Training: Batch 141/208. Loss of 0.6937, cover loss of 0.0043, secret loss of 0.6894
# Training: Batch 142/208. Loss of 0.5043, cover loss of 0.0035, secret loss of 0.5008
# Training: Batch 143/208. Loss of 0.8431, cover loss of 0.0026, secret loss of 0.8405
# Training: Batch 144/208. Loss of 0.6512, cover loss of 0.0059, secret loss of 0.6453
# Training: Batch 145/208. Loss of 0.9814, cover loss of 0.0089, secret loss of 0.9725
# Training: Batch 146/208. Loss of 0.7956, cover loss of 0.0029, secret loss of 0.7927
# Training: Batch 147/208. Loss of 1.1186, cover loss of 0.0068, secret loss of 1.1119
# Training: Batch 148/208. Loss of 0.6123, cover loss of 0.0025, secret loss of 0.6098
# Training: Batch 149/208. Loss of 0.4470, cover loss of 0.0034, secret loss of 0.4436
# Training: Batch 150/208. Loss of 1.5504, cover loss of 0.0227, secret loss of 1.5277
# Training: Batch 151/208. Loss of 2.2834, cover loss of 0.0037, secret loss of 2.2797
# Training: Batch 152/208. Loss of 0.8626, cover loss of 0.0046, secret loss of 0.8580
# Training: Batch 153/208. Loss of 0.6550, cover loss of 0.0199, secret loss of 0.6351
# Training: Batch 154/208. Loss of 1.4888, cover loss of 0.0072, secret loss of 1.4817
# Training: Batch 155/208. Loss of 0.6151, cover loss of 0.0050, secret loss of 0.6100
# Training: Batch 156/208. Loss of 1.1810, cover loss of 0.0046, secret loss of 1.1764
# Training: Batch 157/208. Loss of 0.7606, cover loss of 0.0074, secret loss of 0.7532
# Training: Batch 158/208. Loss of 1.1123, cover loss of 0.0290, secret loss of 1.0833
# Training: Batch 159/208. Loss of 0.8217, cover loss of 0.0049, secret loss of 0.8168
# Training: Batch 160/208. Loss of 1.5381, cover loss of 0.0234, secret loss of 1.5148
# Training: Batch 161/208. Loss of 0.9948, cover loss of 0.0133, secret loss of 0.9815
# Training: Batch 162/208. Loss of 0.5975, cover loss of 0.0081, secret loss of 0.5895
# Training: Batch 163/208. Loss of 1.5562, cover loss of 0.0078, secret loss of 1.5484
# Training: Batch 164/208. Loss of 0.9934, cover loss of 0.0119, secret loss of 0.9815
# Training: Batch 165/208. Loss of 0.9801, cover loss of 0.0092, secret loss of 0.9709
# Training: Batch 166/208. Loss of 0.9935, cover loss of 0.0143, secret loss of 0.9793
# Training: Batch 167/208. Loss of 0.8477, cover loss of 0.0119, secret loss of 0.8358
# Training: Batch 168/208. Loss of 1.3235, cover loss of 0.0165, secret loss of 1.3070
# Training: Batch 169/208. Loss of 0.6999, cover loss of 0.0191, secret loss of 0.6808
# Training: Batch 170/208. Loss of 0.5253, cover loss of 0.0055, secret loss of 0.5198
# Training: Batch 171/208. Loss of 0.9004, cover loss of 0.0154, secret loss of 0.8849
# Training: Batch 172/208. Loss of 0.5252, cover loss of 0.0206, secret loss of 0.5047
# Training: Batch 173/208. Loss of 0.8486, cover loss of 0.0151, secret loss of 0.8335
# Training: Batch 174/208. Loss of 0.7529, cover loss of 0.0138, secret loss of 0.7391
# Training: Batch 175/208. Loss of 0.8840, cover loss of 0.0102, secret loss of 0.8738
# Training: Batch 176/208. Loss of 0.4534, cover loss of 0.0128, secret loss of 0.4406
# Training: Batch 177/208. Loss of 3.0154, cover loss of 0.0120, secret loss of 3.0035
# Training: Batch 178/208. Loss of 0.2403, cover loss of 0.0110, secret loss of 0.2293
# Training: Batch 179/208. Loss of 0.7218, cover loss of 0.0080, secret loss of 0.7138
# Training: Batch 180/208. Loss of 1.3185, cover loss of 0.0048, secret loss of 1.3137
# Training: Batch 181/208. Loss of 0.5753, cover loss of 0.0078, secret loss of 0.5675
# Training: Batch 182/208. Loss of 1.3306, cover loss of 0.0050, secret loss of 1.3256
# Training: Batch 183/208. Loss of 1.8999, cover loss of 0.0255, secret loss of 1.8744
# Training: Batch 184/208. Loss of 1.1646, cover loss of 0.0109, secret loss of 1.1537
# Training: Batch 185/208. Loss of 1.1774, cover loss of 0.0081, secret loss of 1.1693
# Training: Batch 186/208. Loss of 1.2713, cover loss of 0.0093, secret loss of 1.2619
# Training: Batch 187/208. Loss of 0.9619, cover loss of 0.0094, secret loss of 0.9525
# Training: Batch 188/208. Loss of 0.4037, cover loss of 0.0037, secret loss of 0.4001
# Training: Batch 189/208. Loss of 0.8336, cover loss of 0.0037, secret loss of 0.8298
# Training: Batch 190/208. Loss of 1.4148, cover loss of 0.0035, secret loss of 1.4112
# Training: Batch 191/208. Loss of 1.8714, cover loss of 0.0040, secret loss of 1.8674
# Training: Batch 192/208. Loss of 1.4276, cover loss of 0.0076, secret loss of 1.4200
# Training: Batch 193/208. Loss of 0.2889, cover loss of 0.0072, secret loss of 0.2817
# Training: Batch 194/208. Loss of 1.1330, cover loss of 0.0032, secret loss of 1.1299
# Training: Batch 195/208. Loss of 0.7810, cover loss of 0.0035, secret loss of 0.7775
# Training: Batch 196/208. Loss of 0.6979, cover loss of 0.0183, secret loss of 0.6795
# Training: Batch 197/208. Loss of 0.7696, cover loss of 0.0047, secret loss of 0.7650
# Training: Batch 198/208. Loss of 1.1388, cover loss of 0.0117, secret loss of 1.1271
# Training: Batch 199/208. Loss of 0.8964, cover loss of 0.0071, secret loss of 0.8893
# Training: Batch 200/208. Loss of 0.9991, cover loss of 0.0064, secret loss of 0.9927
# Training: Batch 201/208. Loss of 1.6344, cover loss of 0.0033, secret loss of 1.6311
# Training: Batch 202/208. Loss of 0.9835, cover loss of 0.0070, secret loss of 0.9765
# Training: Batch 203/208. Loss of 0.6029, cover loss of 0.0060, secret loss of 0.5969
# Training: Batch 204/208. Loss of 1.1326, cover loss of 0.0030, secret loss of 1.1296
# Training: Batch 205/208. Loss of 1.0973, cover loss of 0.0074, secret loss of 1.0900
# Training: Batch 206/208. Loss of 2.2285, cover loss of 0.0054, secret loss of 2.2231
# Training: Batch 207/208. Loss of 1.1691, cover loss of 0.0087, secret loss of 1.1604
# Training: Batch 208/208. Loss of 0.5756, cover loss of 0.0027, secret loss of 0.5729
# Epoch [3/3], Average_loss: 1.0018

# %%
torch.save(net.state_dict(), '/content/model3')

# %%
# Plot loss through epochs
plt.plot(loss_history)
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Batch')
plt.show()

# %% [markdown]
# We test the model and print out a few images so we can visually see how good a job the model did.

# %%
# net.load_state_dict(torch.load(MODELS_PATH+'Epoch N4.pkl'))

# Switch to evaluate mode
net.eval()

test_losses = []
# Show images
for idx, test_batch in enumerate(test_loader):
     # Saves images
    data, _ = test_batch

    # Saves secret images and secret covers
    test_secret = data[:len(data)//2]
    test_cover = data[len(data)//2:]

    # Creates variable from secret and cover images
    test_secret = Variable(test_secret, volatile=True)
    test_cover = Variable(test_cover, volatile=True)

    # Compute output
    test_hidden, test_output = net(test_secret, test_cover)

    # Calculate loss
    test_loss, loss_cover, loss_secret = customized_loss(test_output, test_hidden, test_secret, test_cover, beta)

#     diff_S, diff_C = np.abs(np.array(test_output.data[0]) - np.array(test_secret.data[0])), np.abs(np.array(test_hidden.data[0]) - np.array(test_cover.data[0]))

#     print (diff_S, diff_C)

    if idx in [1,2,3,4]:
        print ('Total loss: {:.2f} \nLoss on secret: {:.2f} \nLoss on cover: {:.2f}'.format(test_loss.item(), loss_secret.item(), loss_cover.item()))

        # Creates img tensor
        imgs = [test_secret.data, test_output.data, test_cover.data, test_hidden.data]
        imgs_tsor = torch.cat(imgs, 0)

        # Prints Images
        imshow(utils.make_grid(imgs_tsor), idx+1, learning_rate=learning_rate, beta=beta)

    test_losses.append(test_loss.item())

mean_test_loss = np.mean(test_losses)

print ('Average loss on test set: {:.2f}'.format(mean_test_loss))
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:14: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:15: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
#   from ipykernel import kernelapp as app
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:29: UserWarning: nn.init.normal is now deprecated in favor of nn.init.normal_.
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Total loss: 0.66
# Loss on secret: 0.66
# Loss on cover: 0.00
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Total loss: 0.91
# Loss on secret: 0.91
# Loss on cover: 0.01
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Total loss: 1.42
# Loss on secret: 1.41
# Loss on cover: 0.00
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Total loss: 1.28
# Loss on secret: 1.28
# Loss on cover: 0.00
# Average loss on test set: 0.91
